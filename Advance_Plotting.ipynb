# %% [markdown]
# # **HeatMaps**
# A graphical representation of data where values are depicted by colors.
# Heatmaps allow you to spot where something has occured , choice of color palette is important.
#
# Two types of color palette are available :
# 1) Sequential
# 2) Qualitative

# %%
#The inline flag will use appropriate backend to make figures inline in notebook 
# %matplotlib inline 
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Histogram

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-efb4a967-bada-4bac-b1ad-101cd6c0f925" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-efb4a967-bada-4bac-b1ad-101cd6c0f925">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('kingCountyHouseData.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df['price'].head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
#Histogram using pandas

df['price'].hist()
#Default is not good , one solution is to rotate your xticks 
plt.xticks(rotation=90)
# Out:
# (array([-1000000.,        0.,  1000000.,  2000000.,  3000000.,  4000000.,
#          5000000.,  6000000.,  7000000.,  8000000.,  9000000.]),
#  [Text(-1000000.0, 0, '−1'),
#   Text(0.0, 0, '0'),
#   Text(1000000.0, 0, '1'),
#   Text(2000000.0, 0, '2'),
#   Text(3000000.0, 0, '3'),
#   Text(4000000.0, 0, '4'),
#   Text(5000000.0, 0, '5'),
#   Text(6000000.0, 0, '6'),
#   Text(7000000.0, 0, '7'),
#   Text(8000000.0, 0, '8'),
#   Text(9000000.0, 0, '9')])

# %%
df['price'].hist(bins=30)
#Changing the number of bins - seems better
# Out:
# <Axes: >
